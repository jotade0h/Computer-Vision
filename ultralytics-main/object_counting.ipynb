# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov8" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png"></a>
#
#   [中文](https://docs.ultralytics.com/zh/) | [한국어](https://docs.ultralytics.com/ko/) | [日本語](https://docs.ultralytics.com/ja/) | [Русский](https://docs.ultralytics.com/ru/) | [Deutsch](https://docs.ultralytics.com/de/) | [Français](https://docs.ultralytics.com/fr/) | [Español](https://docs.ultralytics.com/es/) | [Português](https://docs.ultralytics.com/pt/) | [हिन्दी](https://docs.ultralytics.com/hi/) | [العربية](https://docs.ultralytics.com/ar/)
#
#   <a href="https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/object_counting.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
# Welcome to the Ultralytics YOLOv8 🚀 notebook! <a href="https://github.com/ultralytics/ultralytics">YOLOv8</a> is the latest version of the YOLO (You Only Look Once) AI models developed by <a href="https://ultralytics.com">Ultralytics</a>. This notebook serves as the starting point for exploring the <a href="https://docs.ultralytics.com/guides/object-counting/">Object Counting</a> and understand its features and capabilities.
#
# YOLOv8 models are fast, accurate, and easy to use, making them ideal for various object detection and image segmentation tasks. They can be trained on large datasets and run on diverse hardware platforms, from CPUs to GPUs.
#
# We hope that the resources in this notebook will help you get the most out of <a href="https://docs.ultralytics.com/guides/object-counting/">Ultralytics Object Counting</a>. Please browse the YOLOv8 <a href="https://docs.ultralytics.com/">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/ultralytics">GitHub</a> for support, and join our <a href="https://ultralytics.com/discord">Discord</a> community for questions and discussions!
#
# </div>

# %% [markdown]
# # Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.

# %%
# !pip install ultralytics

# %% [markdown]
# # Ultralytics Object Counting
#
# Counting objects using Ultralytics YOLOv8 entails the precise detection and enumeration of specific objects within videos and camera streams. YOLOv8 demonstrates exceptional performance in real-time applications, delivering efficient and accurate object counting across diverse scenarios such as crowd analysis and surveillance. This is attributed to its advanced algorithms and deep learning capabilities.

# %%
from ultralytics import YOLO
from ultralytics.solutions import object_counter
import cv2

model = YOLO("yolov8n.pt")
cap = cv2.VideoCapture('rtsp://admin:william1560@192.168.128.4:554/Streaming/channels/301/')
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))

# Define region points
region_points = [(20, 400), (1080, 404), (1080, 360), (20, 360)]

# Video writer
video_writer = cv2.VideoWriter("object_counting_output.avi",
                       cv2.VideoWriter_fourcc(*'mp4v'),
                       fps,
                       (w, h))

# Init Object Counter
counter = object_counter.ObjectCounter()
counter.set_args(view_img=True,
                 reg_pts=region_points,
                 classes_names=model.names,
                 draw_tracks=True)

while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or video processing has been successfully completed.")
        break
    tracks = model.track(im0, persist=True, show=False)

    im0 = counter.start_counting(im0, tracks)
    video_writer.write(im0)

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Polygon Counter Initiated.
#
# 0: 640x576 (no detections), 171.4ms
# Speed: 10.0ms preprocess, 171.4ms inference, 2707.3ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 4 persons, 1 car, 1 motorcycle, 1 bus, 1 truck, 86.8ms
# Speed: 3.5ms preprocess, 86.8ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 4 persons, 4 bicycles, 2 cars, 1 truck, 84.0ms
# Speed: 3.8ms preprocess, 84.0ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 3 persons, 2 cars, 1 truck, 80.9ms
# Speed: 2.0ms preprocess, 80.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 94.6ms
# Speed: 3.0ms preprocess, 94.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 95.2ms
# Speed: 3.8ms preprocess, 95.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 train, 85.2ms
# Speed: 2.8ms preprocess, 85.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 80.3ms
# Speed: 5.0ms preprocess, 80.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 83.3ms
# Speed: 3.0ms preprocess, 83.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 88.3ms
# Speed: 5.0ms preprocess, 88.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 77.6ms
# Speed: 2.0ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 77.3ms
# Speed: 2.7ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 77.4ms
# Speed: 2.0ms preprocess, 77.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 69.8ms
# Speed: 3.5ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 bus, 71.3ms
# Speed: 5.1ms preprocess, 71.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 75.3ms
# Speed: 2.6ms preprocess, 75.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 69.5ms
# Speed: 2.8ms preprocess, 69.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 77.6ms
# Speed: 1.8ms preprocess, 77.6ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 79.2ms
# Speed: 2.9ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 74.4ms
# Speed: 5.8ms preprocess, 74.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 77.0ms
# Speed: 6.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 63.1ms
# Speed: 3.0ms preprocess, 63.1ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 83.5ms
# Speed: 3.5ms preprocess, 83.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 81.5ms
# Speed: 3.6ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 79.8ms
# Speed: 0.9ms preprocess, 79.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 81.2ms
# Speed: 6.4ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 74.1ms
# Speed: 2.5ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 73.3ms
# Speed: 7.1ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 67.7ms
# Speed: 3.0ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 bus, 76.0ms
# Speed: 1.9ms preprocess, 76.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 65.7ms
# Speed: 5.0ms preprocess, 65.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 70.6ms
# Speed: 2.0ms preprocess, 70.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 79.7ms
# Speed: 2.1ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 81.2ms
# Speed: 3.0ms preprocess, 81.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 77.8ms
# Speed: 0.9ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 77.5ms
# Speed: 4.9ms preprocess, 77.5ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 80.8ms
# Speed: 3.0ms preprocess, 80.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 79.4ms
# Speed: 2.0ms preprocess, 79.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 1 truck, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 person, 1 car, 1 bus, 1 truck, 83.2ms
# Speed: 4.5ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 persons, 1 car, 1 truck, 1 parking meter, 100.2ms
# Speed: 3.0ms preprocess, 100.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 79.4ms
# Speed: 3.3ms preprocess, 79.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 74.9ms
# Speed: 2.2ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 70.5ms
# Speed: 3.0ms preprocess, 70.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 81.7ms
# Speed: 2.3ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 71.8ms
# Speed: 5.0ms preprocess, 71.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 truck, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 truck, 69.1ms
# Speed: 2.8ms preprocess, 69.1ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 truck, 75.9ms
# Speed: 3.1ms preprocess, 75.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 truck, 71.3ms
# Speed: 2.0ms preprocess, 71.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 74.5ms
# Speed: 2.1ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 truck, 81.2ms
# Speed: 1.3ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 bus, 76.9ms
# Speed: 2.0ms preprocess, 76.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 truck, 73.5ms
# Speed: 3.1ms preprocess, 73.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 76.4ms
# Speed: 1.6ms preprocess, 76.4ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 train, 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 bus, 75.3ms
# Speed: 3.1ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 81.7ms
# Speed: 0.0ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 73.0ms
# Speed: 2.4ms preprocess, 73.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 bus, 86.5ms
# Speed: 3.3ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 truck, 68.4ms
# Speed: 2.5ms preprocess, 68.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 truck, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 72.5ms
# Speed: 2.0ms preprocess, 72.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 76.3ms
# Speed: 1.8ms preprocess, 76.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 76.0ms
# Speed: 1.8ms preprocess, 76.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 73.4ms
# Speed: 2.0ms preprocess, 73.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 70.7ms
# Speed: 2.0ms preprocess, 70.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 76.4ms
# Speed: 2.9ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 76.3ms
# Speed: 0.0ms preprocess, 76.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 1 bus, 70.9ms
# Speed: 5.3ms preprocess, 70.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 86.2ms
# Speed: 3.5ms preprocess, 86.2ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 person, 1 car, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 71.4ms
# Speed: 2.0ms preprocess, 71.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 67.3ms
# Speed: 2.9ms preprocess, 67.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 1 car, 69.3ms
# Speed: 2.8ms preprocess, 69.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 73.8ms
# Speed: 2.7ms preprocess, 73.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 86.6ms
# Speed: 2.9ms preprocess, 86.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 69.8ms
# Speed: 1.9ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 74.6ms
# Speed: 2.9ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 73.6ms
# Speed: 3.0ms preprocess, 73.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 64.7ms
# Speed: 3.0ms preprocess, 64.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 73.4ms
# Speed: 2.0ms preprocess, 73.4ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 76.4ms
# Speed: 3.0ms preprocess, 76.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 78.4ms
# Speed: 3.3ms preprocess, 78.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 81.1ms
# Speed: 4.5ms preprocess, 81.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 82.2ms
# Speed: 4.5ms preprocess, 82.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 82.8ms
# Speed: 3.9ms preprocess, 82.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 75.1ms
# Speed: 2.5ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x576 2 cars, 69.8ms
# Speed: 2.5ms preprocess, 69.8ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 576)
# Video frame is empty or video processing has been successfully completed.

# %% [markdown]
# #Community Support
#
# For more information, you can explore <a href="https://docs.ultralytics.com/guides/object-counting/">Ultralytics Object Counting Docs</a>
#
# Ultralytics ⚡ resources
# - About Us – https://ultralytics.com/about
# - Join Our Team – https://ultralytics.com/work
# - Contact Us – https://ultralytics.com/contact
# - Discord – https://ultralytics.com/discord
# - Ultralytics License – https://ultralytics.com/license
#
# YOLOv8 🚀 resources
# - GitHub – https://github.com/ultralytics/ultralytics
# - Docs – https://docs.ultralytics.com/
